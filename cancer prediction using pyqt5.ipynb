# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'C:\Users\Admin\Desktop\durga\pyqt5\cancer.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1092, 1158)
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(360, 10, 341, 51))
        self.label.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 0, 255)")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(30, 68, 121, 41))
        self.label_2.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_2.setObjectName("label_2")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(30, 130, 151, 31))
        self.label_4.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(20, 190, 151, 31))
        self.label_5.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(30, 240, 131, 31))
        self.label_6.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(10, 310, 151, 16))
        self.label_7.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(10, 360, 221, 51))
        self.label_8.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)\n"
"\n"
"")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(10, 440, 161, 51))
        self.label_9.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(10, 510, 201, 41))
        self.label_10.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(20, 700, 121, 20))
        self.label_11.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_11.setObjectName("label_11")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(380, 190, 201, 31))
        self.label_13.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(380, 240, 131, 31))
        self.label_14.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Form)
        self.label_15.setGeometry(QtCore.QRect(380, 300, 181, 31))
        self.label_15.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(Form)
        self.label_16.setGeometry(QtCore.QRect(380, 370, 191, 21))
        self.label_16.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(Form)
        self.label_17.setGeometry(QtCore.QRect(380, 450, 161, 21))
        self.label_17.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_17.setObjectName("label_17")
        self.label_18 = QtWidgets.QLabel(Form)
        self.label_18.setGeometry(QtCore.QRect(380, 520, 201, 21))
        self.label_18.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_18.setObjectName("label_18")
        self.label_19 = QtWidgets.QLabel(Form)
        self.label_19.setGeometry(QtCore.QRect(400, 570, 171, 51))
        self.label_19.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_19.setObjectName("label_19")
        self.label_20 = QtWidgets.QLabel(Form)
        self.label_20.setGeometry(QtCore.QRect(380, 630, 251, 41))
        self.label_20.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_20.setObjectName("label_20")
        self.label_21 = QtWidgets.QLabel(Form)
        self.label_21.setGeometry(QtCore.QRect(20, 750, 111, 41))
        self.label_21.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_21.setObjectName("label_21")
        self.label_22 = QtWidgets.QLabel(Form)
        self.label_22.setGeometry(QtCore.QRect(380, 80, 141, 21))
        self.label_22.setStyleSheet("font: 11pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_22.setObjectName("label_22")
        self.label_23 = QtWidgets.QLabel(Form)
        self.label_23.setGeometry(QtCore.QRect(0, 630, 221, 31))
        self.label_23.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_23.setObjectName("label_23")
        self.label_24 = QtWidgets.QLabel(Form)
        self.label_24.setGeometry(QtCore.QRect(10, 570, 171, 41))
        self.label_24.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_24.setObjectName("label_24")
        self.label_25 = QtWidgets.QLabel(Form)
        self.label_25.setGeometry(QtCore.QRect(20, 830, 131, 31))
        self.label_25.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_25.setObjectName("label_25")
        self.label_26 = QtWidgets.QLabel(Form)
        self.label_26.setGeometry(QtCore.QRect(390, 700, 111, 21))
        self.label_26.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_26.setObjectName("label_26")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(390, 760, 121, 31))
        self.label_3.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_3.setObjectName("label_3")
        self.label_27 = QtWidgets.QLabel(Form)
        self.label_27.setGeometry(QtCore.QRect(390, 820, 211, 41))
        self.label_27.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_27.setObjectName("label_27")
        self.label_28 = QtWidgets.QLabel(Form)
        self.label_28.setGeometry(QtCore.QRect(20, 900, 141, 31))
        self.label_28.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_28.setObjectName("label_28")
        self.label_29 = QtWidgets.QLabel(Form)
        self.label_29.setGeometry(QtCore.QRect(390, 890, 171, 41))
        self.label_29.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_29.setObjectName("label_29")
        self.label_30 = QtWidgets.QLabel(Form)
        self.label_30.setGeometry(QtCore.QRect(30, 960, 131, 21))
        self.label_30.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_30.setObjectName("label_30")
        self.label_31 = QtWidgets.QLabel(Form)
        self.label_31.setGeometry(QtCore.QRect(390, 950, 221, 31))
        self.label_31.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_31.setObjectName("label_31")
        self.lineEdit = QtWidgets.QLineEdit(Form)
        self.lineEdit.setGeometry(QtCore.QRect(200, 80, 113, 25))
        self.lineEdit.setObjectName("lineEdit")
        self.lineEdit_2 = QtWidgets.QLineEdit(Form)
        self.lineEdit_2.setGeometry(QtCore.QRect(200, 130, 113, 25))
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(Form)
        self.lineEdit_3.setGeometry(QtCore.QRect(210, 190, 113, 25))
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(Form)
        self.lineEdit_4.setGeometry(QtCore.QRect(210, 240, 113, 25))
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.lineEdit_5 = QtWidgets.QLineEdit(Form)
        self.lineEdit_5.setGeometry(QtCore.QRect(210, 300, 113, 25))
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.lineEdit_6 = QtWidgets.QLineEdit(Form)
        self.lineEdit_6.setGeometry(QtCore.QRect(210, 370, 113, 25))
        self.lineEdit_6.setObjectName("lineEdit_6")
        self.lineEdit_7 = QtWidgets.QLineEdit(Form)
        self.lineEdit_7.setGeometry(QtCore.QRect(210, 450, 113, 25))
        self.lineEdit_7.setObjectName("lineEdit_7")
        self.lineEdit_8 = QtWidgets.QLineEdit(Form)
        self.lineEdit_8.setGeometry(QtCore.QRect(220, 520, 113, 25))
        self.lineEdit_8.setObjectName("lineEdit_8")
        self.lineEdit_9 = QtWidgets.QLineEdit(Form)
        self.lineEdit_9.setGeometry(QtCore.QRect(230, 570, 113, 25))
        self.lineEdit_9.setObjectName("lineEdit_9")
        self.lineEdit_10 = QtWidgets.QLineEdit(Form)
        self.lineEdit_10.setGeometry(QtCore.QRect(230, 630, 113, 25))
        self.lineEdit_10.setObjectName("lineEdit_10")
        self.lineEdit_11 = QtWidgets.QLineEdit(Form)
        self.lineEdit_11.setGeometry(QtCore.QRect(230, 690, 113, 25))
        self.lineEdit_11.setObjectName("lineEdit_11")
        self.lineEdit_12 = QtWidgets.QLineEdit(Form)
        self.lineEdit_12.setGeometry(QtCore.QRect(230, 760, 113, 25))
        self.lineEdit_12.setObjectName("lineEdit_12")
        self.lineEdit_13 = QtWidgets.QLineEdit(Form)
        self.lineEdit_13.setGeometry(QtCore.QRect(220, 830, 113, 25))
        self.lineEdit_13.setObjectName("lineEdit_13")
        self.lineEdit_14 = QtWidgets.QLineEdit(Form)
        self.lineEdit_14.setGeometry(QtCore.QRect(220, 890, 113, 25))
        self.lineEdit_14.setObjectName("lineEdit_14")
        self.lineEdit_15 = QtWidgets.QLineEdit(Form)
        self.lineEdit_15.setGeometry(QtCore.QRect(220, 950, 113, 25))
        self.lineEdit_15.setObjectName("lineEdit_15")
        self.lineEdit_16 = QtWidgets.QLineEdit(Form)
        self.lineEdit_16.setGeometry(QtCore.QRect(640, 240, 113, 25))
        self.lineEdit_16.setObjectName("lineEdit_16")
        self.lineEdit_17 = QtWidgets.QLineEdit(Form)
        self.lineEdit_17.setGeometry(QtCore.QRect(640, 300, 113, 25))
        self.lineEdit_17.setObjectName("lineEdit_17")
        self.lineEdit_18 = QtWidgets.QLineEdit(Form)
        self.lineEdit_18.setGeometry(QtCore.QRect(640, 360, 113, 25))
        self.lineEdit_18.setObjectName("lineEdit_18")
        self.lineEdit_19 = QtWidgets.QLineEdit(Form)
        self.lineEdit_19.setGeometry(QtCore.QRect(640, 450, 113, 25))
        self.lineEdit_19.setObjectName("lineEdit_19")
        self.lineEdit_20 = QtWidgets.QLineEdit(Form)
        self.lineEdit_20.setGeometry(QtCore.QRect(640, 510, 113, 25))
        self.lineEdit_20.setObjectName("lineEdit_20")
        self.lineEdit_21 = QtWidgets.QLineEdit(Form)
        self.lineEdit_21.setGeometry(QtCore.QRect(650, 570, 113, 25))
        self.lineEdit_21.setObjectName("lineEdit_21")
        self.lineEdit_22 = QtWidgets.QLineEdit(Form)
        self.lineEdit_22.setGeometry(QtCore.QRect(640, 640, 113, 25))
        self.lineEdit_22.setObjectName("lineEdit_22")
        self.lineEdit_23 = QtWidgets.QLineEdit(Form)
        self.lineEdit_23.setGeometry(QtCore.QRect(640, 700, 113, 25))
        self.lineEdit_23.setObjectName("lineEdit_23")
        self.lineEdit_24 = QtWidgets.QLineEdit(Form)
        self.lineEdit_24.setGeometry(QtCore.QRect(640, 770, 113, 25))
        self.lineEdit_24.setObjectName("lineEdit_24")
        self.lineEdit_25 = QtWidgets.QLineEdit(Form)
        self.lineEdit_25.setGeometry(QtCore.QRect(640, 830, 113, 25))
        self.lineEdit_25.setObjectName("lineEdit_25")
        self.lineEdit_26 = QtWidgets.QLineEdit(Form)
        self.lineEdit_26.setGeometry(QtCore.QRect(650, 900, 113, 25))
        self.lineEdit_26.setObjectName("lineEdit_26")
        self.lineEdit_27 = QtWidgets.QLineEdit(Form)
        self.lineEdit_27.setGeometry(QtCore.QRect(650, 960, 113, 25))
        self.lineEdit_27.setObjectName("lineEdit_27")
        self.lineEdit_28 = QtWidgets.QLineEdit(Form)
        self.lineEdit_28.setGeometry(QtCore.QRect(640, 80, 113, 25))
        self.lineEdit_28.setObjectName("lineEdit_28")
        self.lineEdit_29 = QtWidgets.QLineEdit(Form)
        self.lineEdit_29.setGeometry(QtCore.QRect(640, 130, 113, 25))
        self.lineEdit_29.setObjectName("lineEdit_29")
        self.lineEdit_30 = QtWidgets.QLineEdit(Form)
        self.lineEdit_30.setGeometry(QtCore.QRect(640, 180, 113, 25))
        self.lineEdit_30.setObjectName("lineEdit_30")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(380, 130, 151, 31))
        self.label_12.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label_12.setObjectName("label_12")
        self.btnadd_2 = QtWidgets.QPushButton(Form)
        self.btnadd_2.setGeometry(QtCore.QRect(930, 410, 112, 34))
        self.btnadd_2.setObjectName("btnadd_2")

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "CANCER  PREDICTION"))
        self.label_2.setText(_translate("Form", "Radius mean"))
        self.label_4.setText(_translate("Form", "texture_mean"))
        self.label_5.setText(_translate("Form", "perimeter_mean"))
        self.label_6.setText(_translate("Form", "area_mean"))
        self.label_7.setText(_translate("Form", "smoothness_mean\n"
""))
        self.label_8.setText(_translate("Form", "compactness_mean"))
        self.label_9.setText(_translate("Form", "concavity_mean"))
        self.label_10.setText(_translate("Form", "concave points_mean"))
        self.label_11.setText(_translate("Form", "radius_se "))
        self.label_13.setText(_translate("Form", "perimeter_worst"))
        self.label_14.setText(_translate("Form", "area_worst"))
        self.label_15.setText(_translate("Form", "smoothness_worst"))
        self.label_16.setText(_translate("Form", "compactness_worst"))
        self.label_17.setText(_translate("Form", "concavity_worst"))
        self.label_18.setText(_translate("Form", "concave points_worst\n"
""))
        self.label_19.setText(_translate("Form", "symmetry_worst\n"
""))
        self.label_20.setText(_translate("Form", " fractal_dimension_worst"))
        self.label_21.setText(_translate("Form", "texture_se"))
        self.label_22.setText(_translate("Form", "radius_worst"))
        self.label_23.setText(_translate("Form", "fractal_dimension_mean "))
        self.label_24.setText(_translate("Form", "symmetry_mean "))
        self.label_25.setText(_translate("Form", "perimeter_se "))
        self.label_26.setText(_translate("Form", "area_se "))
        self.label_3.setText(_translate("Form", "smoothness_se  "))
        self.label_27.setText(_translate("Form", "compactness_se"))
        self.label_28.setText(_translate("Form", "concavity_se   "))
        self.label_29.setText(_translate("Form", "concave points_se"))
        self.label_30.setText(_translate("Form", "symmetry_se  "))
        self.label_31.setText(_translate("Form", "fractal_dimension_se"))
        self.label_12.setText(_translate("Form", "texture_worst"))
        self.btnadd_2.setText(_translate("Form", "submit"))
        
    def cancer(self):
        a = self.label_2.text()
        a1=float(a)
        b = self.label_3.text()
        b1=float(b)
        c = self.label_4.text()
        c1=float(c)
        d = self.label_5.text()
        d1=float(d)
        e = self.label_6.text() 
        e1=float(e)
        f = self.label_7.text()
        f1=float(f)
        g = self.label_8.text()
        g1=float(g)
        h = self.label_9.text()
        h1=float(h)
        i = self.label_10.text()
        i1=float(i)
        j = self.label_11.text()
        j1=float(j)
        k = self.label_12.text()
        k1=float(k)
        l = self.label_13.text()
        l1 = float(l)
        m = self.label_14.text()
        m1 = float(m)
        n = self.label_15.text()
        n1 = float(n)
        o = self.label_16.text()
        o1 = float(o)
        p = self.label_17.text()
        p1 = float(p)
        q = self.label_18.text()
        q1 = float(q)
        r = self.label_19.text()
        r1= float(r)
        s= self.label_20.text()
        s1 = float(s)
        t = self.label_21.text()
        t1 = float(t)
        u = self.label_22.text()
        u1 = float(u)
        v = self.label_23.text()
        v1 = float(v)
        w = self.label_24.text()
        w1 = float(w)
        x = self.label_25.text()
        x1 = float(x)
        y = self.label_26.text()
        y1 = float(y)
        z = self.label_27.text()
        z1 = float(z)
        aa= self.label_28.text()
        aa1 = float(aa)
        bb = self.label_29.text()
        bb1 = float(bb)
        cc = self.label_30.text()
        cc1= float(cc)
        dd = self.label_31.text()
        dd1= float(dd)    
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
data = pd.read_csv("C:\\Users\\Admin\\Desktop\\durga\\Newdatasets\\Cancer prediction\\data.csv")

data= data.dropna(axis=1)
labelencoder_Y = LabelEncoder()
data.iloc[:,1] = labelencoder_Y.fit_transform(data.iloc[:,1].values)
data.iloc[:,1]

sns.pairplot(data.iloc[:,1:5])
sns.pairplot(data.iloc[:,1:5],hue = 'diagnosis')
data.iloc[:,1:12].corr()

x = data.iloc[:,2:31].values
y = data.iloc[:,1].values
x_train,x_test,y_train,y_test = train_test_split(x , y,test_size = 0.25,random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
log = LogisticRegression(random_state=0)
log.fit(x_train,y_train)
print(log.score(x_train,y_train))
y_pred= log.predict(x_test)

print(y_pred)
print(y_test)
y_pred[1:5]
prediction = ["M" if x < 0.5 else "B" for x in y_pred]
prediction[1:5]
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test,y_pred)
cnf_matrix
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))
print("precision:",metrics.precision_score(y_test,y_pred))
print("recall:",metrics.recall_score(y_test,y_pred))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
